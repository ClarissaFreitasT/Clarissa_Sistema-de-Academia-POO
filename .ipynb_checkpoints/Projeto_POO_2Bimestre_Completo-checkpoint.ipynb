# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
class Treino:
    def __init__(self, nome, tipo, duracao):
        self.nome = nome
        self.tipo = tipo
        self.duracao = duracao

    def exibir_detalhes(self):
        print(f"Treino: {self.nome}")
        print(f"Tipo: {self.tipo}")
        print(f"Duração: {self.duracao}")
        print("-" * 30)

treino1= Treino("Corrida", "Cardio", "40 min")
treino2 = Treino("Musculação","Força", "50 min")  

treino1.exibir_detalhes()
treino2.exibir_detalhes()
# Out:
# Treino: Corrida
# Tipo: Cardio
# Duração: 40 min
# ------------------------------
# Treino: Musculação
# Tipo: Força
# Duração: 50 min
# ------------------------------

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
class Treino:
    def __init__(self, nome, tipo, duracao):
        self.nome = nome
        self.tipo = tipo
        self.duracao = duracao

    def exibir_detalhes(self):
        print(f"Treino: {self.nome}")
        print(f"Tipo: {self.tipo}")
        print(f"Duração: {self.duracao}")
        print("-" * 30)

    def alterar_duracao(self, nova_duracao):
        self.duracao = nova_duracao
        print(f"A duração do treino '{self.nome}' foi alterada para {self.duracao} minutos.")

    def alterar_tipo(self, novo_tipo):
        self.tipo = novo_tipo
        print(f"O tipo do treino '{self.nome}' foi alterado para {self.tipo}.")

class TreinoForça(Treino):
    def __init__(self, nome, duracao, serie):
        super().__init__(nome, "força", duracao)
        self.serie = serie 

    def exibir_detalhes_forca(self):
        print(f"O treino '{self.nome}' teve {self.serie} séries.")

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class Usuario:
    def __init__(self, nome, idade, email):
        self.__nome = nome        
        self.__idade = idade        
        self.__email = email        
 
    def get_idade(self):
        return self.__idade
   
    def set_idade(self, idade):
        self.__idade = idade      
   
   
    def get_nome(self):
        return self.__nome
   
    def set_nome(self, nome):
        self.__nome = nome


   
    def exibir_dados(self):
        print(f"Nome: {self.__nome}")
        print(f"Idade: {self.__idade}")
        print(f"Email: {self.__email}")


   
class Treino:
    def __init__(self, nome, tipo, duracao, usuario):
        self.nome = nome 
        self.tipo = tipo                  
        self.duracao = duracao            
        self.__usuario = usuario        




    def exibir_detalhes(self):
        print(f"Detalhes do treino:")
        print(f"Nome do treino: {self.nome}")
        print(f"Tipo: {self.tipo}")
        print(f"Duração: {self.duracao} minutos")
        print(f"Informações do usuário:")
        self.__usuario.exibir_dados()  




   
    def realizar_treino(self):
        print(f"Iniciando treino: {self.nome}")
        print(f"Tipo: {self.tipo} - Duração: {self.duracao} minutos")
        print(f"Realizando treino para o usuário {self.__usuario.get_nome()}...")

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in c:\users\clarissa_teixeira\appdata\roaming\python\python311\site-packages (9.3.0)

# %%
# Desenvolva aqui o código da Parte 4
import mysql.connector


def conectar():
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="",
        database="sistema_treino"  
    )

def criar_tabelas():
    conn = conectar()
    cursor = conn.cursor()

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS usuarios (
            id INT AUTO_INCREMENT PRIMARY KEY,
            nome VARCHAR(100) NOT NULL,
            idade INT NOT NULL,
            email VARCHAR(100) NOT NULL UNIQUE
        )
    """)

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS treinos (
            id INT AUTO_INCREMENT PRIMARY KEY,
            nome VARCHAR(100) NOT NULL,
            tipo ENUM('cardio', 'forca') NOT NULL,
            duracao INT NOT NULL,
            usuario_id INT,
            FOREIGN KEY (usuario_id) REFERENCES usuarios(id) ON DELETE SET NULL
        )
    """)

    conn.commit()
    cursor.close()
    conn.close()
    print("✅ Tabelas criadas (se não existirem).")


def inserir_usuario(usuario):
    conn = conectar()
    cursor = conn.cursor()
    try:
        cursor.execute("""
            INSERT INTO usuarios (nome, idade, email) VALUES (%s, %s, %s)
        """, (usuario.get_nome(), usuario.get_idade(), usuario.get_email()))
        conn.commit()
        print("✅ Usuário cadastrado com sucesso!")
    except mysql.connector.IntegrityError:
        print("⚠️ Email já cadastrado.")
    cursor.close()
    conn.close()

def obter_usuario_por_email(email):
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("SELECT id, nome, idade, email FROM usuarios WHERE email = %s", (email,))
    resultado = cursor.fetchone()
    cursor.close()
    conn.close()
    return resultado

def inserir_treino(nome, tipo, duracao, usuario_email):
    usuario = obter_usuario_por_email(usuario_email)
    if not usuario:
        print("⚠️ Usuário não encontrado. Cadastre o usuário primeiro.")
        return

    usuario_id = usuario[0]
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("""
        INSERT INTO treinos (nome, tipo, duracao, usuario_id) VALUES (%s, %s, %s, %s)
    """, (nome, tipo, duracao, usuario_id))
    conn.commit()
    cursor.close()
    conn.close()
    print("✅ Treino cadastrado com sucesso!")

def listar_treinos():
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("""
        SELECT t.id, t.nome, t.tipo, t.duracao, u.nome FROM treinos t
        LEFT JOIN usuarios u ON t.usuario_id = u.id
    """)
    treinos = cursor.fetchall()
    cursor.close()
    conn.close()

    if treinos:
        print("\n📋 Treinos cadastrados:")
        for treino in treinos:
            print(f"ID: {treino[0]} | Nome: {treino[1]} | Tipo: {treino[2]} | Duração: {treino[3]} min | Usuário: {treino[4]}")
    else:
        print("⚠️ Nenhum treino cadastrado.")

def excluir_treino(id_treino):
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("DELETE FROM treinos WHERE id = %s", (id_treino,))
    conn.commit()
    cursor.close()
    conn.close()
    print("🗑️ Treino excluído com sucesso!")


class Usuario:
    def __init__(self, nome, idade, email):
        self.nome = nome
        self.idade = idade
        self.email = email
    
    def get_nome(self):
        return self.nome
    
    def get_idade(self):
        return self.idade
    
    def get_email(self):
        return self.email


usuario1 = Usuario("Lucas", 24, "lucas2@email.com")  
inserir_usuario(usuario1)
# Out:
# ✅ Usuário cadastrado com sucesso!

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in c:\users\clarissa_teixeira\appdata\roaming\python\python311\site-packages (9.3.0)

# %%
import mysql.connector  # Importa a biblioteca para conectar com o banco MySQL


# =========================
# CONFIGURAÇÃO DO BANCO
# =========================


# Função que conecta ao banco de dados
def conectar():
    return mysql.connector.connect(
        host="localhost",        # Endereço do servidor MySQL
        user="root",             # Nome de usuário do banco
        password="",             # Senha do banco (vazio por padrão local)
        database="sistema_treino"  # Nome do banco de dados a ser usado
    )


# Cria as tabelas do banco se ainda não existirem
def criar_tabelas():
    conn = conectar()
    cursor = conn.cursor()


    # Cria a tabela de usuários
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS usuarios (
            id INT AUTO_INCREMENT PRIMARY KEY,
            nome VARCHAR(100) NOT NULL,
            idade INT NOT NULL,
            email VARCHAR(100) NOT NULL UNIQUE
        )
    """)


    # Cria a tabela de treinos com chave estrangeira para usuários
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS treinos (
            id INT AUTO_INCREMENT PRIMARY KEY,
            nome VARCHAR(100) NOT NULL,
            tipo ENUM('cardio', 'forca') NOT NULL,
            duracao INT NOT NULL,
            usuario_id INT,
            FOREIGN KEY (usuario_id) REFERENCES usuarios(id) ON DELETE SET NULL
        )
    """)


    conn.commit()        # Salva as mudanças no banco
    cursor.close()
    conn.close()
    print("✅ Tabelas criadas (se não existirem).")


# =========================
# CLASSES
# =========================


# Representa um usuário com seus dados
class Usuario:
    def __init__(self, nome, idade, email):
        self.__nome = nome
        self.__idade = idade
        self.__email = email


    def get_nome(self):
        return self.__nome


    def get_idade(self):
        return self.__idade


    def get_email(self):
        return self.__email


    def exibir_dados(self):
        print(f"Nome: {self.__nome}")
        print(f"Idade: {self.__idade}")
        print(f"Email: {self.__email}")


# Representa um treino genérico
class Treino:
    def __init__(self, nome, tipo, duracao, usuario):
        self.nome = nome
        self.tipo = tipo
        self.duracao = duracao
        self.__usuario = usuario  # Usuário é passado como objeto


    def exibir_detalhes(self):
        print("Detalhes do treino:")
        print(f"Nome do treino: {self.nome}")
        print(f"Tipo: {self.tipo}")
        print(f"Duração: {self.duracao} minutos")
        print("Informações do usuário:")
        self.__usuario.exibir_dados()


    def realizar_treino(self):
        print(f"Iniciando treino: {self.nome}")
        print(f"Tipo: {self.tipo} - Duração: {self.duracao} minutos")
        print(f"Usuário: {self.__usuario.get_nome()}")


# Representa um treino específico de força
class TreinoForca(Treino):
    def realizar_treino(self):
        print(f"🏋️‍♂️ Treino de FORÇA iniciado: {self.nome}")
        print(f"Tipo: {self.tipo} - Duração: {self.duracao} minutos")
        print("Prepare-se para levantar peso!")


# =========================
# FUNÇÕES DE BANCO
# =========================


# Insere um usuário no banco
def inserir_usuario(usuario):
    conn = conectar()
    cursor = conn.cursor()
    try:
        cursor.execute("""
            INSERT INTO usuarios (nome, idade, email) VALUES (%s, %s, %s)
        """, (usuario.get_nome(), usuario.get_idade(), usuario.get_email()))
        conn.commit()
        print("✅ Usuário cadastrado com sucesso!")
    except mysql.connector.IntegrityError:
        print("⚠️ Email já cadastrado.")  # Evita duplicidade de emails
    cursor.close()
    conn.close()


# Busca um usuário pelo email no banco
def obter_usuario_por_email(email):
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("SELECT id, nome, idade, email FROM usuarios WHERE email = %s", (email,))
    resultado = cursor.fetchone()
    cursor.close()
    conn.close()
    return resultado


# Insere um treino no banco associado a um usuário
def inserir_treino(nome, tipo, duracao, usuario_email):
    usuario = obter_usuario_por_email(usuario_email)
    if not usuario:
        print("⚠️ Usuário não encontrado. Cadastre o usuário primeiro.")
        return


    usuario_id = usuario[0]  # Pega o ID do usuário
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("""
        INSERT INTO treinos (nome, tipo, duracao, usuario_id) VALUES (%s, %s, %s, %s)
    """, (nome, tipo, duracao, usuario_id))
    conn.commit()
    cursor.close()
    conn.close()
    print("✅ Treino cadastrado com sucesso!")


# Lista todos os treinos cadastrados com o nome do usuário
def listar_treinos():
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("""
        SELECT t.id, t.nome, t.tipo, t.duracao, u.nome FROM treinos t
        LEFT JOIN usuarios u ON t.usuario_id = u.id
    """)
    treinos = cursor.fetchall()
    cursor.close()
    conn.close()


    if treinos:
        print("\n📋 Treinos cadastrados:")
        for treino in treinos:
            print(f"ID: {treino[0]} | Nome: {treino[1]} | Tipo: {treino[2]} | Duração: {treino[3]} min | Usuário: {treino[4]}")
    else:
        print("⚠️ Nenhum treino cadastrado.")


# Exclui um treino pelo ID
def excluir_treino(id_treino):
    conn = conectar()
    cursor = conn.cursor()
    cursor.execute("DELETE FROM treinos WHERE id = %s", (id_treino,))
    conn.commit()
    cursor.close()
    conn.close()
    print("🗑️ Treino excluído com sucesso!")


# =========================
# MENU INTERATIVO
# =========================


# Função principal de interação com o usuário
def menu():
    criar_tabelas()  # Garante que as tabelas existem
    print("Bem-vindo ao Sistema de Treinos!")


    # Cadastro inicial do usuário
    nome = input("Nome do usuário: ")
    idade = int(input("Idade: "))
    email = input("Email: ")
    usuario = Usuario(nome, idade, email)
    inserir_usuario(usuario)


    while True:
        print("\n--- MENU ---")
        print("1. Cadastrar treino")
        print("2. Listar treinos")
        print("3. Excluir treino")
        print("4. Simular treino de força")
        print("0. Sair")
        opcao = input("Escolha uma opção: ")


        if opcao == "1":
            nome_treino = input("Nome do treino: ")
            tipo = input("Tipo (cardio/forca): ").lower()
            duracao = int(input("Duração (minutos): "))
            inserir_treino(nome_treino, tipo, duracao, email)


        elif opcao == "2":
            listar_treinos()


        elif opcao == "3":
            id_treino = int(input("ID do treino a excluir: "))
            excluir_treino(id_treino)


        elif opcao == "4":
            nome_treino = input("Nome do treino de força: ")
            duracao = int(input("Duração: "))
            treino = TreinoForca(nome_treino, "forca", duracao, usuario)
            treino.realizar_treino()


        elif opcao == "0":
            print("Encerrando o sistema.")
            break


        else:
            print("Opção inválida.")


# =========================
# EXECUÇÃO
# =========================


menu()  # Inicia o programa
# Out:
# ✅ Tabelas criadas (se não existirem).
# Bem-vindo ao Sistema de Treinos!
